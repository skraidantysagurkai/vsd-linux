# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.shared.json_tools import load_json_long
from paths import DATA_DIR
import os

known_attack_dataset = []
directory = DATA_DIR / 'commands'

def recursive_load_jsons(directory):
    for entry in os.scandir(directory):
        if entry.is_dir():
            recursive_load_jsons(entry.path)
        elif entry.is_file() and entry.name.endswith('.json'):
            try:
                data = load_json_long(entry.path)
                known_attack_dataset.append(data)
            except Exception as e:
                print(f"Failed to load {entry.path}: {e}")
                
recursive_load_jsons(directory)

# %%
len(known_attack_dataset)
# Out:
# 267

# %%
types = [i["cmd_type"] for logs in known_attack_dataset for i in logs]

# %%
set(types)
# Out:
# {'bash-command', 'msf-command'}

# %%
import random as rd
def convert_command_entry(entry):
    try:
        timestamp = ''
    
        # Extract command and arguments
        cmd_parts = entry['cmd'].split()
        pid = rd.randint(1000, 99999) 
    
        # Base structure
        syscall_entry = {
            "timestamp": timestamp,
            "success": 1,
            "uid": "1000" if entry.get("username") != "root" else "0",
            "euid": "0" if entry.get("username") == "root" else "1000",
            "syscall": "0",
            "ppid": pid,
            "pid": pid,
            "command": cmd_parts[0],
            "arguments": cmd_parts,
            "CWD": entry.get("wd", "/")
        }
    
        return syscall_entry
    except Exception as e:
        return 0

dt = [[convert_command_entry(entry) for entry in logs] for logs in known_attack_dataset]

# %%
dt = [[entry for entry in logs if entry != 0 ] for logs in dt]

# %%
len([entry for logs in dt for entry in logs])
# Out:
# 21089

# %%
from pathlib import Path
good_data = []
for log_file in Path(DATA_DIR / 'old').glob('*.json'):
    logs = load_json_long(log_file)
    logs = [i["content"] for i in logs if i["target"] < 0.5]
    good_data.append(logs)

# %%
len(good_data)
# Out:
# 13

# %%
len([entry for logs in good_data for entry in logs])
# Out:
# 71852

# %%
len(dt)
# Out:
# 267

# %%
good_data = [entry for logs in good_data for entry in logs]

# %%
transformed_mixed_data = []
for bad_subset in dt:
    random_num = rd.randint(1, 3)
    random_length = rd.randint(int(len(bad_subset) * 0.75), int(len(bad_subset) * 1.5))
    good_subset = good_data[:random_length]
    good_data = good_data[random_length:]
    
    if random_num == 1:
        transformed_mixed_data.append(good_subset + bad_subset)
    elif random_num == 2:
        transformed_mixed_data.append(bad_subset + good_subset)
    else:
        transformed_mixed_data.append(rd.shuffle(good_subset + bad_subset))

# %%
len(good_data)
# Out:
# 48403

# %%
def generate_random_subsets(data, num_subsets=270, min_len=91, max_len=252):
    subsets = []
    for _ in range(num_subsets):
        k = rd.randint(min_len, min(max_len, len(data)))  # ensure k ≤ len(data)
        subset = rd.sample(data, k)
        subsets.append(subset)
    return subsets

good_data = generate_random_subsets(good_data, num_subsets=270, min_len=91, max_len=252)

# %%
len(good_data)
# Out:
# 270

# %%
good_data[0][0]
# Out:
# {'timestamp': '1704027385.152',
#  'success': 1,
#  'uid': '1000',
#  'euid': '0',
#  'syscall': '0',
#  'ppid': '7953',
#  'pid': '7953',
#  'command': 'mkdir',
#  'arguments': ['mkdir',
#   '-p',
#   '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/stmicro/stmmac'],
#  'CWD': '/'}

# %%
import random
import time
from datetime import datetime, timedelta

def add_random_timestamps(events):
    # Start with a random date in 2025
    start_dt = datetime(
        year=2025,
        month=random.randint(1, 12),
        day=random.randint(1, 28),  # Keep it simple for all months
        hour=random.randint(0, 23),
        minute=random.randint(0, 59),
        second=random.randint(0, 59)
    )
    
    current_dt = start_dt

    for event in events:
        # Convert to epoch with microseconds as string
        event["timestamp"] = f"{current_dt.timestamp():.3f}"
        # Add a random time delta (3s to 240s) for the next event
        delta_seconds = random.randint(3, 240)
        current_dt += timedelta(seconds=delta_seconds)

    return events

add_random_timestamps(good_data[0])
# Out:
# [{'timestamp': '1765392099.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '7953',
#   'pid': '7953',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/stmicro/stmmac'],
#   'CWD': '/'},
#  {'timestamp': '1765392156.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '14207',
#   'pid': '14207',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/net/ethernet/sis/sis190.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765392246.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '18548',
#   'pid': '18548',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/ata/pata_hpt37x.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765392371.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '9149',
#   'pid': '9149',
#   'command': 'sed',
#   'arguments': None,
#   'CWD': None},
#  {'timestamp': '1765392580.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '27262',
#   'pid': '27262',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/drivers/char/hw_random'],
#   'CWD': '/'},
#  {'timestamp': '1765392709.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '34158',
#   'pid': '34158',
#   'command': 'apt-config',
#   'arguments': ['apt-config', 'shell', 'EtcDir', 'Dir::Etc'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765392800.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1408',
#   'pid': '1408',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765393013.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '33337',
#   'pid': '33337',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '3063'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765393187.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1408',
#   'pid': '1408',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765393277.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '41859',
#   'pid': '41859',
#   'command': 'find',
#   'arguments': ['find',
#    '/proc/40237/fd',
#    '-ignore_readdir_race',
#    '-lname',
#    '/var/lib/php/sessions/sess_*',
#    '-exec',
#    'touch',
#    '-c',
#    '{}',
#    ';'],
#   'CWD': '/'},
#  {'timestamp': '1765393301.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '31909',
#   'pid': '31909',
#   'command': 'cpio',
#   'arguments': ['cpio', '--quiet', '-o', '-H', 'newc'],
#   'CWD': '/var/tmp/mkinitramfs_IBhfXc'},
#  {'timestamp': '1765393498.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'dpkg-query',
#   'arguments': ['dpkg-query',
#    '-W',
#    "-f='${binary:Package}t${Status}t${db:Status-Status}n'",
#    'talk'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765393555.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '9390',
#   'pid': '9390',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/scsi/aacraid'],
#   'CWD': '/'},
#  {'timestamp': '1765393721.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '45166',
#   'pid': '45166',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '2066'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765393959.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '8656',
#   'pid': '8656',
#   'command': 'awk',
#   'arguments': None,
#   'CWD': None},
#  {'timestamp': '1765394015.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5962',
#   'pid': '5962',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/hid/hid-nintendo.ko',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/hid/hid-nintendo.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765394248.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '35360',
#   'pid': '35360',
#   'command': 'dpkg',
#   'arguments': None,
#   'CWD': '/'},
#  {'timestamp': '1765394301.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '27296',
#   'pid': '27296',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/net/usb/catc.ko',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/drivers/net/usb/catc.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765394449.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '23974',
#   'pid': '23974',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/usr/lib/initramfs-tools/bin/wait-for-root',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/sbin/wait-for-root'],
#   'CWD': '/'},
#  {'timestamp': '1765394580.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '2867',
#   'pid': '2867',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '226'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765394687.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765394717.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '35631',
#   'pid': '35631',
#   'command': 'dpkg',
#   'arguments': None,
#   'CWD': '/'},
#  {'timestamp': '1765394778.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '27296',
#   'pid': '27296',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/lib/polynomial.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765395007.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '35926',
#   'pid': '35926',
#   'command': 'dpkg',
#   'arguments': ['dpkg',
#    '--compare-versions',
#    '--',
#    '5.64-0ubuntu1',
#    'le-nl',
#    '3.7-1'],
#   'CWD': '/'},
#  {'timestamp': '1765395061.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '14310',
#   'pid': '14310',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/x86_64-linux-gnu/libnss_dns.so.2',
#    '/var/tmp/mkinitramfs_e2XAqT//usr/lib/x86_64-linux-gnu/libnss_dns.so.2'],
#   'CWD': '/'},
#  {'timestamp': '1765395147.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '45693',
#   'pid': '45693',
#   'command': 'systemctl',
#   'arguments': ['systemctl',
#    'show',
#    'rc-local.service',
#    '--property=ActiveState'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765395275.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1380',
#   'pid': '1380',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765395515.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '10840',
#   'pid': '10840',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/x86_64-linux-gnu'],
#   'CWD': '/'},
#  {'timestamp': '1765395727.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '29585',
#   'pid': '29585',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/drivers/ata'],
#   'CWD': '/'},
#  {'timestamp': '1765395751.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '46502',
#   'pid': '46502',
#   'command': '10-help-text',
#   'arguments': ['/bin/sh', '/etc/update-motd.d/10-help-text'],
#   'CWD': '/'},
#  {'timestamp': '1765395839.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '3788',
#   'pid': '3788',
#   'command': 'cracklib-runtim',
#   'arguments': ['/bin/sh', '/etc/cron.daily/cracklib-runtime'],
#   'CWD': '/'},
#  {'timestamp': '1765395940.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765396097.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '3986',
#   'pid': '3986',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765396270.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '35146',
#   'pid': '35146',
#   'command': 'dirname',
#   'arguments': ['dirname', '/var/lib/update-notifier/updates-available'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765396509.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1408',
#   'pid': '1408',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765396636.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '31218',
#   'pid': '31218',
#   'command': 'ln',
#   'arguments': ['ln',
#    '/var/tmp/mkinitramfs_IBhfXc/bin/busybox',
#    '/var/tmp/mkinitramfs_IBhfXc/bin/rmdir'],
#   'CWD': '/'},
#  {'timestamp': '1765396660.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '22778',
#   'pid': '22778',
#   'command': 'dpkg',
#   'arguments': ['/usr/bin/dpkg', '--print-foreign-architectures'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765396841.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '27296',
#   'pid': '27296',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/intel/fm10k/fm10k.ko',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/intel/fm10k/fm10k.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765396891.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '16545',
#   'pid': '16545',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/char/hw_random/xiphera-trng.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765397106.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '7953',
#   'pid': '7953',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/wiznet/w5300.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765397191.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'dpkg-query',
#   'arguments': ['dpkg-query', '-s', 'samba'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765397240.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '46101',
#   'pid': '46101',
#   'command': 'awk',
#   'arguments': ['awk', '-F='],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765397261.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '29922',
#   'pid': '29922',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/usb/storage/ums-datafab.ko',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/drivers/usb/storage/ums-datafab.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765397372.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '48825',
#   'pid': '48825',
#   'command': 'appstreamcli',
#   'arguments': ['appstreamcli', 'refresh-cache'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765397490.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765397709.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765397815.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '16175',
#   'pid': '16175',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/ata/pata_amd.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765397849.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '26122',
#   'pid': '26122',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/regulator/wm831x-ldo.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765398031.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1380',
#   'pid': '1380',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765398087.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '20355',
#   'pid': '20355',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pnL',
#    '/usr/lib/klibc/bin/cpio',
#    '/var/tmp/mkinitramfs_e2XAqT/bin'],
#   'CWD': '/'},
#  {'timestamp': '1765398239.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '14207',
#   'pid': '14207',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/net/usb/ax88179_178a.ko',
#    '/var/tmp/mkinitramfs_oOffJR//usr/lib/modules/6.2.0-36-generic/kernel/drivers/net/usb/ax88179_178a.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765398434.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '13359',
#   'pid': '13359',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_oOffJR//usr/lib/modules/6.2.0-36-generic/kernel/drivers/regulator'],
#   'CWD': '/'},
#  {'timestamp': '1765398583.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '14004',
#   'pid': '14004',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '11032'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765398662.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765398674.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5678',
#   'pid': '5678',
#   'command': 'readlink',
#   'arguments': ['readlink', '-f', '/etc/modprobe.d/blacklist-oss.conf'],
#   'CWD': '/'},
#  {'timestamp': '1765398776.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '38783',
#   'pid': '38783',
#   'command': 'udevadm',
#   'arguments': ['udevadm', 'info', '--query', 'path', '--name', '/dev/sda3'],
#   'CWD': '/'},
#  {'timestamp': '1765398783.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '15641',
#   'pid': '15641',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_oOffJR//usr/lib/modules/6.2.0-36-generic/kernel/drivers/scsi/bnx2i'],
#   'CWD': '/'},
#  {'timestamp': '1765398837.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1464',
#   'pid': '1464',
#   'command': 'dpkg',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765398877.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '9390',
#   'pid': '9390',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/firmware/qlogic/1280.bin',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/firmware/qlogic/1280.bin'],
#   'CWD': '/'},
#  {'timestamp': '1765399106.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1408',
#   'pid': '1408',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765399119.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '45750',
#   'pid': '45750',
#   'command': 'cmp',
#   'arguments': ['cmp', '-s', 'dpkg.arch.0', '/var/lib/dpkg/arch'],
#   'CWD': '/var/backups'},
#  {'timestamp': '1765399196.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '12191',
#   'pid': '12191',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/hid/hid-ft260.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765399432.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '7133',
#   'pid': '7133',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/regulator/max8998.ko',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/regulator/max8998.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765399530.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '14207',
#   'pid': '14207',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/vhost/vhost_iotlb.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765399590.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '36258',
#   'pid': '36258',
#   'command': 'dpkg',
#   'arguments': ['/usr/bin/dpkg', '--print-foreign-architectures'],
#   'CWD': '/var/backups'},
#  {'timestamp': '1765399817.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '45341',
#   'pid': '45341',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '2886'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765399933.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '36630',
#   'pid': '36630',
#   'command': 'grep',
#   'arguments': ['grep', '-q', '/etc/locale.gen'],
#   'CWD': '/'},
#  {'timestamp': '1765400100.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765400291.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '18347',
#   'pid': '18347',
#   'command': 'systemd-getty-g',
#   'arguments': ['/usr/lib/systemd/system-generators/systemd-getty-generator',
#    '/run/systemd/generator',
#    '/run/systemd/generator.early',
#    '/run/systemd/generator.late'],
#   'CWD': '/'},
#  {'timestamp': '1765400388.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '2726',
#   'pid': '2726',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '101'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765400521.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '12191',
#   'pid': '12191',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/hid/intel-ish-hid/intel-ishtp-loader.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765400669.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '7953',
#   'pid': '7953',
#   'command': 'readlink',
#   'arguments': ['readlink',
#    '-f',
#    '/lib/firmware/netronome/nic_AMDA0081-0001_4x10.nffw'],
#   'CWD': '/'},
#  {'timestamp': '1765400783.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '36630',
#   'pid': '36630',
#   'command': 'grep',
#   'arguments': ['grep', '-q', '/etc/locale.gen'],
#   'CWD': '/'},
#  {'timestamp': '1765400838.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '25720',
#   'pid': '25720',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/mfd/rt4831.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765400950.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '20546',
#   'pid': '20546',
#   'command': 'dpkg',
#   'arguments': ['/usr/bin/dpkg', '--print-foreign-architectures'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765401059.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1448',
#   'pid': '1448',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765401276.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5644',
#   'pid': '5644',
#   'command': 'deb-systemd-hel',
#   'arguments': ['/usr/bin/perl',
#    '/usr/bin/deb-systemd-helper',
#    'unmask',
#    'gpu-manager.service'],
#   'CWD': '/'},
#  {'timestamp': '1765401368.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1408',
#   'pid': '1408',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765401534.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '10268',
#   'pid': '10268',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/fs/jfs/jfs.ko',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/fs/jfs/jfs.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765401642.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1683',
#   'pid': '1683',
#   'command': 'mysql',
#   'arguments': ['/usr/bin/mysql',
#    '--defaults-file=/etc/mysql/debian.cnf',
#    '--skip-column-names',
#    '--silent',
#    '--batch',
#    '--force',
#    '-e'],
#   'CWD': '/'},
#  {'timestamp': '1765401688.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '14182',
#   'pid': '14182',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/char/hw_random/xiphera-trng.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765401698.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5962',
#   'pid': '5962',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/acpi/platform_profile.ko',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/acpi/platform_profile.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765401900.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '43566',
#   'pid': '43566',
#   'command': 'dpkg',
#   'arguments': ['/usr/bin/dpkg', '--print-foreign-architectures'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765401925.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '20355',
#   'pid': '20355',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pnL',
#    '/usr/lib/klibc/bin/run-init',
#    '/var/tmp/mkinitramfs_e2XAqT/bin'],
#   'CWD': '/'},
#  {'timestamp': '1765402093.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '36500',
#   'pid': '36500',
#   'command': 'dpkg',
#   'arguments': ['/usr/bin/dpkg', '--print-foreign-architectures'],
#   'CWD': '/var/backups'},
#  {'timestamp': '1765402169.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '36630',
#   'pid': '36630',
#   'command': 'grep',
#   'arguments': ['grep', '-q', '/etc/locale.gen'],
#   'CWD': '/'},
#  {'timestamp': '1765402221.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '25720',
#   'pid': '25720',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/dma/idma64.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765402228.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '7953',
#   'pid': '7953',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/stmicro/stmmac/stmmac-platform.ko',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/stmicro/stmmac/stmmac-platform.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765402239.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '2939',
#   'pid': '2939',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '645'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765402398.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '20608',
#   'pid': '20608',
#   'command': 'dpkg',
#   'arguments': ['/usr/bin/dpkg', '--print-foreign-architectures'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765402415.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '20602',
#   'pid': '20602',
#   'command': 'apt-config',
#   'arguments': ['apt-config', 'shell', 'ListDir', 'Dir::State::Lists'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765402450.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '34401',
#   'pid': '34401',
#   'command': 'release-upgrade',
#   'arguments': ['/bin/sh',
#    '-e',
#    '/usr/lib/ubuntu-release-upgrader/release-upgrade-motd'],
#   'CWD': '/'},
#  {'timestamp': '1765402613.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '16175',
#   'pid': '16175',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/ata/pata_hpt37x.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765402719.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'dpkg-query',
#   'arguments': ['dpkg-query',
#    '-W',
#    "-f='${binary:Package}t${Status}t${db:Status-Status}n'",
#    'dovecot-imapd'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765402724.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '7953',
#   'pid': '7953',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/huawei/hinic/hinic.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765402906.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '29064',
#   'pid': '29064',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '88'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765403074.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '29392',
#   'pid': '29392',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '188'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765403115.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '47342',
#   'pid': '47342',
#   'command': 'sed',
#   'arguments': ['sed'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765403276.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '41237',
#   'pid': '41237',
#   'command': 'awk',
#   'arguments': ['awk', '-F='],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765403457.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '34317',
#   'pid': '34317',
#   'command': 'dpkg',
#   'arguments': None,
#   'CWD': '/'},
#  {'timestamp': '1765403539.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5622',
#   'pid': '5622',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765403547.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '10268',
#   'pid': '10268',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/fs/nfs/nfsv4.ko',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/fs/nfs/nfsv4.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765403658.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '2693',
#   'pid': '2693',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '91'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765403854.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '26638',
#   'pid': '26638',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/spi/spi-pci1xxxx.ko',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/drivers/spi/spi-pci1xxxx.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765403900.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '14207',
#   'pid': '14207',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/net/ethernet/qlogic/qla3xxx.ko',
#    '/var/tmp/mkinitramfs_oOffJR//usr/lib/modules/6.2.0-36-generic/kernel/drivers/net/ethernet/qlogic/qla3xxx.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765404020.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1448',
#   'pid': '1448',
#   'command': 'dpkg',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765404170.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5622',
#   'pid': '5622',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765404243.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '29990',
#   'pid': '29990',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/fs/btrfs/btrfs.ko',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/fs/btrfs/btrfs.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765404355.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '18664',
#   'pid': '18664',
#   'command': 'sort',
#   'arguments': ['sort', '-k', '4', '-g'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765404489.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '37551',
#   'pid': '37551',
#   'command': 'apt-config',
#   'arguments': ['apt-config', 'shell', 'ListDir', 'Dir::State::Lists'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765404539.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '3450',
#   'pid': '3450',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '1886'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765404728.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '46334',
#   'pid': '46334',
#   'command': 'sed',
#   'arguments': ['sed'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765404965.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '27296',
#   'pid': '27296',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/drivers/net/phy'],
#   'CWD': '/'},
#  {'timestamp': '1765404997.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1408',
#   'pid': '1408',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765405021.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '13718',
#   'pid': '13718',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_oOffJR//usr/lib/modules/6.2.0-36-generic/kernel/drivers/spi'],
#   'CWD': '/'},
#  {'timestamp': '1765405135.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '19442',
#   'pid': '19442',
#   'command': 'cpio',
#   'arguments': ['cpio', '--usage'],
#   'CWD': '/'},
#  {'timestamp': '1765405242.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '36630',
#   'pid': '36630',
#   'command': 'grep',
#   'arguments': ['grep', '-q', '/etc/locale.gen'],
#   'CWD': '/'},
#  {'timestamp': '1765405283.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1408',
#   'pid': '1408',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765405515.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '23502',
#   'pid': '23502',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/tmp'},
#  {'timestamp': '1765405597.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '22911',
#   'pid': '22911',
#   'command': 'helpztags',
#   'arguments': ['/usr/bin/perl',
#    '/usr/bin/helpztags',
#    '/usr/share/vim/addons/doc'],
#   'CWD': '/'},
#  {'timestamp': '1765405649.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765405745.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '9733',
#   'pid': '9733',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/block/paride'],
#   'CWD': '/'},
#  {'timestamp': '1765405963.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '21581',
#   'pid': '21581',
#   'command': 'sed',
#   'arguments': ['sed', '-e', 's,+,\\\\+,'],
#   'CWD': '/'},
#  {'timestamp': '1765406120.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '19149',
#   'pid': '19149',
#   'command': 'ld-linux-x86-64',
#   'arguments': ['/lib64/ld-linux-x86-64.so.2', '--help'],
#   'CWD': '/'},
#  {'timestamp': '1765406292.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '27296',
#   'pid': '27296',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/8390/pcnet_cs.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765406316.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '32661',
#   'pid': '32661',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '2193'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765406480.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '17991',
#   'pid': '17991',
#   'command': 'basename',
#   'arguments': ['basename', '/usr/lib/klibc/bin/fstype'],
#   'CWD': '/'},
#  {'timestamp': '1765406492.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1448',
#   'pid': '1448',
#   'command': 'nft',
#   'arguments': ['nft', 'list', 'ruleset'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765406596.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '26638',
#   'pid': '26638',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/lib/bch.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765406677.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '13292',
#   'pid': '13292',
#   'command': 'mkdir',
#   'arguments': ['mkdir',
#    '-p',
#    '/var/tmp/mkinitramfs_oOffJR//usr/lib/modules/6.2.0-36-generic/kernel/drivers/pinctrl/intel'],
#   'CWD': '/'},
#  {'timestamp': '1765406901.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '35859',
#   'pid': '35859',
#   'command': 'dpkg-maintscrip',
#   'arguments': ['/bin/sh',
#    '/usr/bin/dpkg-maintscript-helper',
#    'mv_conffile',
#    '/etc/dbus-1/system.d/bluez-hcid.conf',
#    '/etc/dbus-1/system.d/bluetooth.conf',
#    '3.7-1',
#    'bluez',
#    '--',
#    'upgrade',
#    '5.64-0ubuntu1.1'],
#   'CWD': '/'},
#  {'timestamp': '1765406925.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '21419',
#   'pid': '21419',
#   'command': 'dpkg-preconfigu',
#   'arguments': None,
#   'CWD': '/var/backups'},
#  {'timestamp': '1765407130.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '38735',
#   'pid': '38735',
#   'command': 'udevadm',
#   'arguments': ['udevadm', 'info', '--query', 'path', '--name', '/dev/sda3'],
#   'CWD': '/'},
#  {'timestamp': '1765407315.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '47149',
#   'pid': '47149',
#   'command': 'systemctl',
#   'arguments': None,
#   'CWD': None},
#  {'timestamp': '1765407483.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '25720',
#   'pid': '25720',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/mfd/88pm80x.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765407516.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1448',
#   'pid': '1448',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765407652.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '31237',
#   'pid': '31237',
#   'command': 'sed',
#   'arguments': ['sed',
#    '-e',
#    's#/lib/\\([^/]*/\\)\\?\\(tls\\|i686\\|sse2\\|neon\\|vfp\\).*/\\(lib.*\\)#/lib/\\1\\3#'],
#   'CWD': '/'},
#  {'timestamp': '1765407876.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '14207',
#   'pid': '14207',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/net/ntb_netdev.ko',
#    '/var/tmp/mkinitramfs_oOffJR//usr/lib/modules/6.2.0-36-generic/kernel/drivers/net/ntb_netdev.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765408001.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '3986',
#   'pid': '3986',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765408100.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '1380',
#   'pid': '1380',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765408297.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '4998',
#   'pid': '4998',
#   'command': 'rm',
#   'arguments': ['rm', '-rf', '--', '/var/lib/dpkg/tmp.ci'],
#   'CWD': '/'},
#  {'timestamp': '1765408388.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '9145',
#   'pid': '9145',
#   'command': 'awk',
#   'arguments': ['awk', '-F='],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765408563.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '16570',
#   'pid': '16570',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/net/ethernet/wangxun/libwx/libwx.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765408605.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '28891',
#   'pid': '28891',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/scsi/ch.ko',
#    '/var/tmp/mkinitramfs_IBhfXc//usr/lib/modules/6.2.0-39-generic/kernel/drivers/scsi/ch.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765408782.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '29344',
#   'pid': '29344',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/block/paride/friq.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765408963.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '9924',
#   'pid': '9924',
#   'command': 'cp',
#   'arguments': ['cp',
#    '-pP',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/ata/pata_atiixp.ko',
#    '/var/tmp/mkinitramfs_ex6deS//usr/lib/modules/6.2.0-39-generic/kernel/drivers/ata/pata_atiixp.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765409183.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '41135',
#   'pid': '41135',
#   'command': 'grep',
#   'arguments': ['grep', '[/]etc/rc.local'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765409280.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '27296',
#   'pid': '27296',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/cadence/macb_pci.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765409390.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'stat',
#   'arguments': ['stat', '/etc/cron.hourly/'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765409415.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '33388',
#   'pid': '33388',
#   'command': 'ps',
#   'arguments': ['/bin/ps', '-p', '3083'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765409432.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '3955',
#   'pid': '3955',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765409490.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5612',
#   'pid': '5612',
#   'command': 'sh',
#   'arguments': ['sh', '-c'],
#   'CWD': '/var/ossec'},
#  {'timestamp': '1765409570.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '7953',
#   'pid': '7953',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-39-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-39-generic/kernel/drivers/net/ethernet/amd/pcnet32.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765409798.000',
#   'success': 1,
#   'uid': '1000',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '11909',
#   'pid': '11909',
#   'command': 'modprobe',
#   'arguments': ['modprobe',
#    '--all',
#    '--set-version=6.2.0-36-generic',
#    '--quiet',
#    '--show-depends',
#    'rtc-88pm860x',
#    'rtc-ds1307',
#    'rtc-max6916',
#    'rtc-ds1685',
#    'rtc-ds1511',
#    'rtc-rp5c01',
#    'rtc-wm831x',
#    'rtc-da9063',
#    'rtc-max8907',
#    'rtc-tps65910',
#    'rtc-r9701',
#    'rtc-ab-b5ze-s3',
#    'rtc-m41t93',
#    'rtc-m48t86',
#    'rtc-pcf8523',
#    'rtc-max8998',
#    'rtc-m48t59',
#    'rtc-bq32k',
#    'rtc-wm8350',
#    'rtc-fm3130',
#    'rtc-ds1553',
#    'rtc-rs5c348',
#    'rtc-ftrtc010',
#    'rtc-ds3232',
#    'rtc-ds1286',
#    'rtc-rv8803',
#    'rtc-pcf2123',
#    'rtc-ds1302',
#    'rtc-rc5t583',
#    'rtc-ds1347',
#    'rtc-em3027',
#    'rtc-max6902',
#    'rtc-pcf85063',
#    'rtc-pcf8583',
#    'rtc-ds2404',
#    'rtc-da9055',
#    'rtc-pcf8563',
#    'rtc-pcf2127',
#    'rtc-s35390a',
#    'rtc-ds1672',
#    'rtc-m41t94',
#    'rtc-rv3028',
#    'rtc-max8997',
#    'rtc-goldfish',
#    'rtc-rx8025',
#    'rtc-da9052',
#    'rtc-ab-eoz9',
#    'rtc-pcap',
#    'rtc-rv3032',
#    'rtc-hid-sensor-time',
#    'rtc-rx8010',
#    'rtc-max6900',
#    'rtc-mt6397',
#    'rtc-rv3029c2',
#    'rtc-max8925',
#    'rtc-rx4581',
#    'rtc-msm6242',
#    'rtc-sd3078',
#    'rtc-rx8581',
#    'rtc-ds1305',
#    'rtc-x1205',
#    'rtc-m41t80',
#    'rtc-ds1390',
#    'rtc-pcf85363',
#    'rtc-pcf50633',
#    'rtc-abx80x',
#    'rtc-isl1208',
#    'rtc-mc13xxx',
#    'rtc-ds1742',
#    'rtc-v3020',
#    'rtc-isl12022',
#    'rtc-stk17ta8',
#    'rtc-m48t35',
#    'rtc-cros-ec',
#    'rtc-mcp795',
#    'rtc-rs5c372',
#    'rtc-palmas',
#    'rtc-rx6110',
#    'rtc-tps6586x',
#    'rtc-ds1374',
#    'rtc-ds1343',
#    'rtc-lp8788',
#    'rtc-bq4802',
#    'rtc-88pm80x',
#    'rtc-wilco-ec'],
#   'CWD': '/'},
#  {'timestamp': '1765409959.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '18012',
#   'pid': '18012',
#   'command': 'modinfo',
#   'arguments': ['modinfo',
#    '-k',
#    '6.2.0-36-generic',
#    '-F',
#    'firmware',
#    '/lib/modules/6.2.0-36-generic/kernel/drivers/scsi/BusLogic.ko'],
#   'CWD': '/'},
#  {'timestamp': '1765410049.000',
#   'success': 1,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '22949',
#   'pid': '22949',
#   'command': 'sed',
#   'arguments': ['sed', 's/@VIMCUR@/vim72c/'],
#   'CWD': '/'},
#  {'timestamp': '1765410172.000',
#   'success': 0,
#   'uid': '4294967295',
#   'euid': '0',
#   'syscall': '0',
#   'ppid': '5630',
#   'pid': '5630',
#   'command': 'wazuh-modulesd',
#   'arguments': None,
#   'CWD': '/var/ossec'}]

# %%
good_data = [add_random_timestamps(logs) for logs in good_data]

# %%
transformed_mixed_data = [i for i in transformed_mixed_data if i is not None and len(i) > 0]

# %%
transformed_mixed_data = [add_random_timestamps(logs) for logs in transformed_mixed_data]

# %%
from src.shared.json_tools import write_json_long

for i, logs in enumerate(transformed_mixed_data):
    write_json_long(logs, DATA_DIR / 'testing_data' / 'malicious' / f"{i}.json")
    
for i, logs in enumerate(good_data):
    write_json_long(logs, DATA_DIR / 'testing_data' / 'benign' / f"{i}.json")
